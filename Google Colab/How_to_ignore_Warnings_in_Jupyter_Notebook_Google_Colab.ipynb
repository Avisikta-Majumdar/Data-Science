# %% [markdown]
# ## **What is Warnings ?**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## To remove the pink color box we have to write two lines of code to **ignore this FutureWarning**

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## After writting this code ,let's see is the error again come or not ??

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### ✌ The warning gone😎
